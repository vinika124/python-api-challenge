# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/palak124/opt/anaconda3/lib/python3.9/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/palak124/opt/anaconda3/lib/python3.9/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Print to logger
print("Beginning Data Retrieval    ")
print("--------------------------- ")

url = f"https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# list of city data
city_data = []

# create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list

for i, city in enumerate(cities):
    
    # group the cities in sets of 50 for logging purposes
    if(i % 50 == 0 and i >= 50):
        # reset the group every 50 counts of cities
        set_count += 1
        record_count = 1
    
    # create the endpoint url for each city
    city_url = f"{url}&q={city}"
    
    # log the record and the set number
    print(f"Processing city #{record_count} in group #{set_count} | {city}")
    record_count += 1
    
    try:
        # run API requests and retrieve the data
        city_weather = requests.get(city_url).json()
        
        # add a time delay to avoid blowing out the API key
        time.sleep(2)
        
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the City information into city_data LIST
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        
        
    except:
        # if an error occurs when making the API call, skip the city
        print(f"{city} has an error. Skipping...")
        pass
    
# Indicate that Data Loading is complete
print("----------------------------")
print("Data Retrieval Complete     ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing city #1 in group #1 | hilo
# Processing city #2 in group #1 | rocha
# Processing city #3 in group #1 | rock sound
# Processing city #4 in group #1 | hualmay
# Processing city #5 in group #1 | attawapiskat
# attawapiskat has an error. Skipping...
# Processing city #6 in group #1 | riyadh
# Processing city #7 in group #1 | isangel
# Processing city #8 in group #1 | bredasdorp
# Processing city #9 in group #1 | madang
# Processing city #10 in group #1 | vaini
# Processing city #11 in group #1 | nanortalik
# Processing city #12 in group #1 | chail
# Processing city #13 in group #1 | punta arenas
# Processing city #14 in group #1 | hermanus
# Processing city #15 in group #1 | trogir
# Processing city #16 in group #1 | phuket
# Processing city #17 in group #1 | bluff
# Processing city #18 in group #1 | xiaoweizhai
# Processing city #19 in group #1 | hithadhoo
# Processing city #20 in group #1 | illoqqortoormiut
# illoqqortoormiut has an error. Skipping...
# Processing city #21 in group #1 | souillac
# Processing city #22 in group #1 | mar del plata
# Processing city #23 in group #1 | saleaula
# saleaula has an error. Skipping...
# Processing city #24 in group #1 | kirkwall
# Processing city #25 in group #1 | ancud
# Processing city #26 in group #1 | bilibino
# Processing city #27 in group #1 | pevek
# Processing city #28 in group #1 | poronaysk
# Processing city #29 in group #1 | barrow
# Processing city #30 in group #1 | barentsburg
# barentsburg has an error. Skipping...
# Processing city #31 in group #1 | hit
# Processing city #32 in group #1 | yellowknife
# Processing city #33 in group #1 | taolanaro
# taolanaro has an error. Skipping...
# Processing city #34 in group #1 | klaksvik
# Processing city #35 in group #1 | mareeba
# Processing city #36 in group #1 | mataura
# Processing city #37 in group #1 | tolaga bay
# Processing city #38 in group #1 | kropotkin
# Processing city #39 in group #1 | khatanga
# Processing city #40 in group #1 | atuona
# Processing city #41 in group #1 | busselton
# Processing city #42 in group #1 | muhos
# Processing city #43 in group #1 | slave lake
# Processing city #44 in group #1 | ushuaia
# Processing city #45 in group #1 | dikson
# Processing city #46 in group #1 | la asuncion
# Processing city #47 in group #1 | skotterud
# Processing city #48 in group #1 | lima
# Processing city #49 in group #1 | faanui
# Processing city #50 in group #1 | ilulissat
# Processing city #1 in group #2 | crotone
# Processing city #2 in group #2 | lagoa
# Processing city #3 in group #2 | cape town
# Processing city #4 in group #2 | luderitz
# Processing city #5 in group #2 | manhush
# Processing city #6 in group #2 | half moon bay
# Processing city #7 in group #2 | touros
# Processing city #8 in group #2 | bowen
# Processing city #9 in group #2 | prince rupert
# Processing city #10 in group #2 | seoul
# Processing city #11 in group #2 | longyearbyen
# Processing city #12 in group #2 | hamilton
# Processing city #13 in group #2 | plavinas
# Processing city #14 in group #2 | rangoon
# Processing city #15 in group #2 | atasu
# Processing city #16 in group #2 | lompoc
# Processing city #17 in group #2 | pangnirtung
# Processing city #18 in group #2 | mayo
# Processing city #19 in group #2 | thompson
# Processing city #20 in group #2 | chuy
# Processing city #21 in group #2 | mulege
# Processing city #22 in group #2 | lata
# Processing city #23 in group #2 | paulista
# Processing city #24 in group #2 | rikitea
# Processing city #25 in group #2 | szamotuly
# Processing city #26 in group #2 | hunza
# hunza has an error. Skipping...
# Processing city #27 in group #2 | mainit
# Processing city #28 in group #2 | nanakuli
# Processing city #29 in group #2 | port alfred
# Processing city #30 in group #2 | pisco
# Processing city #31 in group #2 | lorengau
# Processing city #32 in group #2 | esperance
# Processing city #33 in group #2 | east london
# Processing city #34 in group #2 | jumla
# Processing city #35 in group #2 | hobart
# Processing city #36 in group #2 | vila velha
# Processing city #37 in group #2 | sayyan
# Processing city #38 in group #2 | port elizabeth
# Processing city #39 in group #2 | hamburg
# Processing city #40 in group #2 | cherskiy
# Processing city #41 in group #2 | diamantino
# Processing city #42 in group #2 | senador jose porfirio
# Processing city #43 in group #2 | kapaa
# Processing city #44 in group #2 | albany
# Processing city #45 in group #2 | nemuro
# Processing city #46 in group #2 | stephenville
# Processing city #47 in group #2 | srikakulam
# Processing city #48 in group #2 | waipawa
# Processing city #49 in group #2 | higuey
# higuey has an error. Skipping...
# Processing city #50 in group #2 | filadelfia
# Processing city #1 in group #3 | zhigansk
# Processing city #2 in group #3 | ferme-neuve
# Processing city #3 in group #3 | codrington
# Processing city #4 in group #3 | kruisfontein
# Processing city #5 in group #3 | vidim
# Processing city #6 in group #3 | bayan
# Processing city #7 in group #3 | nobres
# Processing city #8 in group #3 | vaitupu
# vaitupu has an error. Skipping...
# Processing city #9 in group #3 | fortuna
# Processing city #10 in group #3 | mount gambier
# Processing city #11 in group #3 | jamestown
# Processing city #12 in group #3 | nhulunbuy
# Processing city #13 in group #3 | sabla
# Processing city #14 in group #3 | new norfolk
# Processing city #15 in group #3 | lakes entrance
# Processing city #16 in group #3 | walvis bay
# Processing city #17 in group #3 | igrim
# Processing city #18 in group #3 | nchelenge
# Processing city #19 in group #3 | kasongo-lunda
# Processing city #20 in group #3 | sitka
# Processing city #21 in group #3 | hengyang
# Processing city #22 in group #3 | butaritari
# Processing city #23 in group #3 | clyde river
# Processing city #24 in group #3 | harper
# Processing city #25 in group #3 | lubango
# Processing city #26 in group #3 | nikolskoye
# Processing city #27 in group #3 | jati
# Processing city #28 in group #3 | amderma
# amderma has an error. Skipping...
# Processing city #29 in group #3 | georgetown
# Processing city #30 in group #3 | saint george
# Processing city #31 in group #3 | bairnsdale
# Processing city #32 in group #3 | hojai
# Processing city #33 in group #3 | port hardy
# Processing city #34 in group #3 | tsihombe
# tsihombe has an error. Skipping...
# Processing city #35 in group #3 | coueron
# Processing city #36 in group #3 | san jose
# Processing city #37 in group #3 | gabu
# Processing city #38 in group #3 | bereda
# Processing city #39 in group #3 | illapel
# Processing city #40 in group #3 | udachnyy
# Processing city #41 in group #3 | sulangan
# Processing city #42 in group #3 | bambous virieux
# Processing city #43 in group #3 | siguiri
# Processing city #44 in group #3 | biltine
# Processing city #45 in group #3 | henties bay
# Processing city #46 in group #3 | bathsheba
# Processing city #47 in group #3 | leningradskiy
# Processing city #48 in group #3 | ahipara
# Processing city #49 in group #3 | takoradi
# Processing city #50 in group #3 | ginda
# Processing city #1 in group #4 | hazebrouck
# Processing city #2 in group #4 | saint-philippe
# Processing city #3 in group #4 | grindavik
# Processing city #4 in group #4 | abbeville
# Processing city #5 in group #4 | aripuana
# Processing city #6 in group #4 | bengkulu
# Processing city #7 in group #4 | lasa
# Processing city #8 in group #4 | inta
# Processing city #9 in group #4 | yumen
# Processing city #10 in group #4 | gaspe
# Processing city #11 in group #4 | lebu
# Processing city #12 in group #4 | northam
# Processing city #13 in group #4 | mondlo
# Processing city #14 in group #4 | mets parni
# Processing city #15 in group #4 | carnarvon
# Processing city #16 in group #4 | sao raimundo nonato
# Processing city #17 in group #4 | dongkan
# Processing city #18 in group #4 | te anau
# Processing city #19 in group #4 | santa cruz cabralia
# Processing city #20 in group #4 | qaanaaq
# Processing city #21 in group #4 | nuevo progreso
# Processing city #22 in group #4 | fairbanks
# Processing city #23 in group #4 | ust-kuyga
# Processing city #24 in group #4 | bethel
# Processing city #25 in group #4 | beloha
# Processing city #26 in group #4 | oga
# Processing city #27 in group #4 | hami
# Processing city #28 in group #4 | arraial do cabo
# Processing city #29 in group #4 | talnakh
# Processing city #30 in group #4 | alyangula
# Processing city #31 in group #4 | castro
# Processing city #32 in group #4 | birao
# Processing city #33 in group #4 | broome
# Processing city #34 in group #4 | bloomingdale
# Processing city #35 in group #4 | victoria
# Processing city #36 in group #4 | wajir
# Processing city #37 in group #4 | saldanha
# Processing city #38 in group #4 | quang ngai
# Processing city #39 in group #4 | puerto ayora
# Processing city #40 in group #4 | mys shmidta
# mys shmidta has an error. Skipping...
# Processing city #41 in group #4 | otjimbingwe
# Processing city #42 in group #4 | avarua
# Processing city #43 in group #4 | celestun
# Processing city #44 in group #4 | san patricio
# Processing city #45 in group #4 | saskylakh
# Processing city #46 in group #4 | salihorsk
# Processing city #47 in group #4 | malanje
# Processing city #48 in group #4 | port lincoln
# Processing city #49 in group #4 | aracatuba
# Processing city #50 in group #4 | pangkalanbuun
# Processing city #1 in group #5 | komsomolskiy
# Processing city #2 in group #5 | sioux lookout
# Processing city #3 in group #5 | warmbad
# Processing city #4 in group #5 | tuktoyaktuk
# Processing city #5 in group #5 | coria
# Processing city #6 in group #5 | cayenne
# Processing city #7 in group #5 | bolgatanga
# Processing city #8 in group #5 | dunedin
# Processing city #9 in group #5 | mayen
# Processing city #10 in group #5 | tiksi
# Processing city #11 in group #5 | banda aceh
# Processing city #12 in group #5 | smithers
# Processing city #13 in group #5 | oranjemund
# Processing city #14 in group #5 | norman wells
# Processing city #15 in group #5 | wenling
# Processing city #16 in group #5 | torbay
# Processing city #17 in group #5 | upernavik
# Processing city #18 in group #5 | ranot
# Processing city #19 in group #5 | nouadhibou
# Processing city #20 in group #5 | vilhena
# Processing city #21 in group #5 | palmer
# Processing city #22 in group #5 | ribeira grande
# Processing city #23 in group #5 | flinders
# Processing city #24 in group #5 | anadyr
# Processing city #25 in group #5 | camacha
# Processing city #26 in group #5 | meyungs
# meyungs has an error. Skipping...
# Processing city #27 in group #5 | mafinga
# Processing city #28 in group #5 | magdagachi
# Processing city #29 in group #5 | varnavino
# Processing city #30 in group #5 | ballina
# Processing city #31 in group #5 | marcona
# marcona has an error. Skipping...
# Processing city #32 in group #5 | tuatapere
# Processing city #33 in group #5 | kuvshinovo
# Processing city #34 in group #5 | almeirim
# Processing city #35 in group #5 | tumannyy
# tumannyy has an error. Skipping...
# Processing city #36 in group #5 | airai
# Processing city #37 in group #5 | akdepe
# Processing city #38 in group #5 | bafq
# bafq has an error. Skipping...
# Processing city #39 in group #5 | wanning
# Processing city #40 in group #5 | chokurdakh
# Processing city #41 in group #5 | haines junction
# Processing city #42 in group #5 | khash
# Processing city #43 in group #5 | vitim
# Processing city #44 in group #5 | matara
# Processing city #45 in group #5 | mujiayingzi
# Processing city #46 in group #5 | coihaique
# Processing city #47 in group #5 | san cristobal
# Processing city #48 in group #5 | yangambi
# Processing city #49 in group #5 | neiafu
# Processing city #50 in group #5 | fare
# Processing city #1 in group #6 | mount pleasant
# Processing city #2 in group #6 | teknaf
# Processing city #3 in group #6 | katsuura
# Processing city #4 in group #6 | tromso
# Processing city #5 in group #6 | nizhneyansk
# nizhneyansk has an error. Skipping...
# Processing city #6 in group #6 | turukhansk
# Processing city #7 in group #6 | ijaki
# ijaki has an error. Skipping...
# Processing city #8 in group #6 | yatou
# Processing city #9 in group #6 | malakal
# Processing city #10 in group #6 | louisbourg
# louisbourg has an error. Skipping...
# Processing city #11 in group #6 | kuznetsk
# Processing city #12 in group #6 | pochutla
# Processing city #13 in group #6 | marrakesh
# Processing city #14 in group #6 | chemal
# Processing city #15 in group #6 | vanavara
# Processing city #16 in group #6 | san jeronimo
# Processing city #17 in group #6 | namatanai
# Processing city #18 in group #6 | farafangana
# Processing city #19 in group #6 | calama
# Processing city #20 in group #6 | forbes
# Processing city #21 in group #6 | correntina
# Processing city #22 in group #6 | kaitangata
# Processing city #23 in group #6 | sumenep
# Processing city #24 in group #6 | worthington
# Processing city #25 in group #6 | samusu
# samusu has an error. Skipping...
# Processing city #26 in group #6 | digha
# Processing city #27 in group #6 | tasiilaq
# Processing city #28 in group #6 | baykit
# Processing city #29 in group #6 | laguna
# Processing city #30 in group #6 | gornopravdinsk
# Processing city #31 in group #6 | karamea
# karamea has an error. Skipping...
# Processing city #32 in group #6 | vila
# Processing city #33 in group #6 | vardo
# Processing city #34 in group #6 | gouyave
# Processing city #35 in group #6 | barcelos
# Processing city #36 in group #6 | kidal
# Processing city #37 in group #6 | montgomery
# Processing city #38 in group #6 | vao
# Processing city #39 in group #6 | kungurtug
# Processing city #40 in group #6 | ponta do sol
# Processing city #41 in group #6 | port hedland
# Processing city #42 in group #6 | srednekolymsk
# Processing city #43 in group #6 | carman
# Processing city #44 in group #6 | ikornnes
# Processing city #45 in group #6 | guano
# Processing city #46 in group #6 | talara
# Processing city #47 in group #6 | sterling
# Processing city #48 in group #6 | colac
# Processing city #49 in group #6 | mahebourg
# Processing city #50 in group #6 | rabak
# Processing city #1 in group #7 | flin flon
# Processing city #2 in group #7 | puerto escondido
# Processing city #3 in group #7 | palauig
# Processing city #4 in group #7 | yeppoon
# Processing city #5 in group #7 | scottsboro
# Processing city #6 in group #7 | berwick
# Processing city #7 in group #7 | hervey bay
# Processing city #8 in group #7 | tabou
# Processing city #9 in group #7 | moron
# Processing city #10 in group #7 | havre-saint-pierre
# Processing city #11 in group #7 | evanston
# Processing city #12 in group #7 | gat
# Processing city #13 in group #7 | primero de enero
# Processing city #14 in group #7 | novo aripuana
# Processing city #15 in group #7 | eganville
# Processing city #16 in group #7 | mankovo-kalitvenskoye
# mankovo-kalitvenskoye has an error. Skipping...
# Processing city #17 in group #7 | hasaki
# Processing city #18 in group #7 | labuhan
# Processing city #19 in group #7 | dingle
# Processing city #20 in group #7 | nome
# Processing city #21 in group #7 | tondano
# Processing city #22 in group #7 | sur
# Processing city #23 in group #7 | preili
# Processing city #24 in group #7 | rey bouba
# Processing city #25 in group #7 | rush
# Processing city #26 in group #7 | novikovo
# Processing city #27 in group #7 | terekli-mekteb
# Processing city #28 in group #7 | gander
# Processing city #29 in group #7 | pandan
# Processing city #30 in group #7 | alofi
# Processing city #31 in group #7 | abhar
# Processing city #32 in group #7 | svetlogorsk
# Processing city #33 in group #7 | tazovskiy
# Processing city #34 in group #7 | mbini
# Processing city #35 in group #7 | roros
# Processing city #36 in group #7 | cap malheureux
# Processing city #37 in group #7 | ghanzi
# Processing city #38 in group #7 | karema
# Processing city #39 in group #7 | shache
# Processing city #40 in group #7 | cabo san lucas
# Processing city #41 in group #7 | baracoa
# Processing city #42 in group #7 | san quintin
# Processing city #43 in group #7 | evensk
# Processing city #44 in group #7 | baruun-urt
# Processing city #45 in group #7 | lanzhou
# Processing city #46 in group #7 | chipata
# Processing city #47 in group #7 | port augusta
# Processing city #48 in group #7 | bentiu
# Processing city #49 in group #7 | kadykchan
# kadykchan has an error. Skipping...
# Processing city #50 in group #7 | mayumba
# Processing city #1 in group #8 | tilichiki
# Processing city #2 in group #8 | eyl
# Processing city #3 in group #8 | roma
# Processing city #4 in group #8 | marsabit
# Processing city #5 in group #8 | haverfordwest
# Processing city #6 in group #8 | port keats
# Processing city #7 in group #8 | boguchany
# Processing city #8 in group #8 | tubruq
# tubruq has an error. Skipping...
# Processing city #9 in group #8 | huai mek
# Processing city #10 in group #8 | jalpan
# Processing city #11 in group #8 | kodiak
# Processing city #12 in group #8 | lazaro cardenas
# Processing city #13 in group #8 | kudahuvadhoo
# Processing city #14 in group #8 | lixourion
# Processing city #15 in group #8 | kilmez
# kilmez has an error. Skipping...
# Processing city #16 in group #8 | aketi
# Processing city #17 in group #8 | saint-joseph
# Processing city #18 in group #8 | shingu
# Processing city #19 in group #8 | alice springs
# Processing city #20 in group #8 | bogorodskoye
# Processing city #21 in group #8 | garowe
# Processing city #22 in group #8 | suntar
# Processing city #23 in group #8 | weihe
# Processing city #24 in group #8 | grand gaube
# Processing city #25 in group #8 | itarema
# Processing city #26 in group #8 | palabuhanratu
# palabuhanratu has an error. Skipping...
# Processing city #27 in group #8 | cidreira
# Processing city #28 in group #8 | imeni poliny osipenko
# Processing city #29 in group #8 | bonthe
# Processing city #30 in group #8 | steinbach
# Processing city #31 in group #8 | tateyama
# Processing city #32 in group #8 | rio grande
# Processing city #33 in group #8 | faya
# Processing city #34 in group #8 | miranorte
# miranorte has an error. Skipping...
# Processing city #35 in group #8 | santa cruz
# Processing city #36 in group #8 | sept-iles
# Processing city #37 in group #8 | elko
# Processing city #38 in group #8 | palu
# Processing city #39 in group #8 | inirida
# Processing city #40 in group #8 | havelock
# Processing city #41 in group #8 | ust-bolsheretsk
# ust-bolsheretsk has an error. Skipping...
# Processing city #42 in group #8 | mutare
# Processing city #43 in group #8 | north bend
# Processing city #44 in group #8 | naryan-mar
# Processing city #45 in group #8 | iwanai
# Processing city #46 in group #8 | alihe
# Processing city #47 in group #8 | kabare
# Processing city #48 in group #8 | aklavik
# Processing city #49 in group #8 | havoysund
# Processing city #50 in group #8 | meulaboh
# Processing city #1 in group #9 | westport
# Processing city #2 in group #9 | satun
# Processing city #3 in group #9 | sao filipe
# Processing city #4 in group #9 | khoy
# Processing city #5 in group #9 | khorixas
# Processing city #6 in group #9 | rio gallegos
# Processing city #7 in group #9 | thinadhoo
# Processing city #8 in group #9 | santa maria
# Processing city #9 in group #9 | sao jose da coroa grande
# Processing city #10 in group #9 | bagdarin
# Processing city #11 in group #9 | ripoll
# Processing city #12 in group #9 | leh
# Processing city #13 in group #9 | provideniya
# Processing city #14 in group #9 | egvekinot
# Processing city #15 in group #9 | andilamena
# Processing city #16 in group #9 | adrar
# Processing city #17 in group #9 | asau
# Processing city #18 in group #9 | troitskoye
# Processing city #19 in group #9 | zalantun
# Processing city #20 in group #9 | nuuk
# Processing city #21 in group #9 | corner brook
# Processing city #22 in group #9 | nichinan
# Processing city #23 in group #9 | mutsamudu
# mutsamudu has an error. Skipping...
# Processing city #24 in group #9 | huanan
# Processing city #25 in group #9 | caohai
# Processing city #26 in group #9 | sentyabrskiy
# sentyabrskiy has an error. Skipping...
# Processing city #27 in group #9 | kahului
# Processing city #28 in group #9 | belushya guba
# belushya guba has an error. Skipping...
# Processing city #29 in group #9 | juneau
# Processing city #30 in group #9 | porbandar
# Processing city #31 in group #9 | necochea
# Processing city #32 in group #9 | preobrazheniye
# Processing city #33 in group #9 | gizo
# Processing city #34 in group #9 | ukiah
# Processing city #35 in group #9 | yantongshan
# Processing city #36 in group #9 | xining
# Processing city #37 in group #9 | garmsar
# Processing city #38 in group #9 | kousseri
# Processing city #39 in group #9 | khuzdar
# Processing city #40 in group #9 | haibowan
# haibowan has an error. Skipping...
# Processing city #41 in group #9 | solnechnyy
# Processing city #42 in group #9 | kahramanmaras
# Processing city #43 in group #9 | makakilo city
# Processing city #44 in group #9 | tshikapa
# Processing city #45 in group #9 | wenzhou
# Processing city #46 in group #9 | partizansk
# Processing city #47 in group #9 | cockburn harbour
# cockburn harbour has an error. Skipping...
# Processing city #48 in group #9 | severo-kurilsk
# Processing city #49 in group #9 | padang
# Processing city #50 in group #9 | dwarka
# Processing city #1 in group #10 | buariki
# buariki has an error. Skipping...
# Processing city #2 in group #10 | warqla
# warqla has an error. Skipping...
# Processing city #3 in group #10 | bergen
# Processing city #4 in group #10 | chateaurenard
# Processing city #5 in group #10 | berdigestyakh
# Processing city #6 in group #10 | novokruchininskiy
# Processing city #7 in group #10 | yukuhashi
# Processing city #8 in group #10 | huanren
# Processing city #9 in group #10 | narsaq
# Processing city #10 in group #10 | zverinogolovskoye
# Processing city #11 in group #10 | geraldton
# Processing city #12 in group #10 | chipinge
# Processing city #13 in group #10 | abu dhabi
# Processing city #14 in group #10 | batagay-alyta
# Processing city #15 in group #10 | iracoubo
# Processing city #16 in group #10 | talcahuano
# Processing city #17 in group #10 | challans
# Processing city #18 in group #10 | belaya kholunitsa
# Processing city #19 in group #10 | vestmannaeyjar
# Processing city #20 in group #10 | port-gentil
# Processing city #21 in group #10 | doha
# Processing city #22 in group #10 | safaqis
# safaqis has an error. Skipping...
# Processing city #23 in group #10 | la ronge
# Processing city #24 in group #10 | iqaluit
# Processing city #25 in group #10 | seymour
# Processing city #26 in group #10 | dakar
# Processing city #27 in group #10 | estevan
# Processing city #28 in group #10 | chiredzi
# Processing city #29 in group #10 | coquimbo
# Processing city #30 in group #10 | voorst
# Processing city #31 in group #10 | grand river south east
# grand river south east has an error. Skipping...
# Processing city #32 in group #10 | caucaia
# Processing city #33 in group #10 | sringeri
# Processing city #34 in group #10 | mehamn
# Processing city #35 in group #10 | tessalit
# Processing city #36 in group #10 | bellevue
# Processing city #37 in group #10 | kraste
# kraste has an error. Skipping...
# Processing city #38 in group #10 | naze
# Processing city #39 in group #10 | montbrison
# Processing city #40 in group #10 | bayangol
# Processing city #41 in group #10 | ranau
# Processing city #42 in group #10 | iskateley
# Processing city #43 in group #10 | deputatskiy
# Processing city #44 in group #10 | antofagasta
# Processing city #45 in group #10 | urzhum
# Processing city #46 in group #10 | mitsamiouli
# Processing city #47 in group #10 | vangaindrano
# Processing city #48 in group #10 | bac lieu
# Processing city #49 in group #10 | mimarsinan
# Processing city #50 in group #10 | najran
# Processing city #1 in group #11 | ixtapa
# Processing city #2 in group #11 | umzimvubu
# umzimvubu has an error. Skipping...
# Processing city #3 in group #11 | manono
# Processing city #4 in group #11 | kemin
# Processing city #5 in group #11 | de-kastri
# Processing city #6 in group #11 | salalah
# Processing city #7 in group #11 | sechura
# Processing city #8 in group #11 | tarko-sale
# Processing city #9 in group #11 | derzhavinsk
# Processing city #10 in group #11 | bay roberts
# Processing city #11 in group #11 | mocambique
# mocambique has an error. Skipping...
# Processing city #12 in group #11 | sao miguel do araguaia
# Processing city #13 in group #11 | veraval
# Processing city #14 in group #11 | bongued
# Processing city #15 in group #11 | port moresby
# Processing city #16 in group #11 | umm lajj
# Processing city #17 in group #11 | broken hill
# Processing city #18 in group #11 | mangrol
# Processing city #19 in group #11 | jardim
# Processing city #20 in group #11 | duluth
# Processing city #21 in group #11 | nenjiang
# Processing city #22 in group #11 | muzaffarabad
# Processing city #23 in group #11 | atambua
# Processing city #24 in group #11 | oda
# Processing city #25 in group #11 | indianola
# Processing city #26 in group #11 | poum
# Processing city #27 in group #11 | catarman
# Processing city #28 in group #11 | erbiceni
# Processing city #29 in group #11 | nizwa
# Processing city #30 in group #11 | sao joao do piaui
# Processing city #31 in group #11 | pacific grove
# Processing city #32 in group #11 | caicedo
# Processing city #33 in group #11 | shibganj
# Processing city #34 in group #11 | quibdo
# Processing city #35 in group #11 | constitucion
# Processing city #36 in group #11 | porto santo
# Processing city #37 in group #11 | zomin
# Processing city #38 in group #11 | husavik
# Processing city #39 in group #11 | severo-yeniseyskiy
# Processing city #40 in group #11 | caravelas
# Processing city #41 in group #11 | pokhara
# Processing city #42 in group #11 | sorland
# Processing city #43 in group #11 | luanda
# Processing city #44 in group #11 | olafsvik
# Processing city #45 in group #11 | yunjinghong
# yunjinghong has an error. Skipping...
# Processing city #46 in group #11 | christchurch
# Processing city #47 in group #11 | biak
# Processing city #48 in group #11 | puerto leguizamo
# Processing city #49 in group #11 | sri aman
# Processing city #50 in group #11 | karaton
# Processing city #1 in group #12 | rodrigues alves
# Processing city #2 in group #12 | fort saint john
# fort saint john has an error. Skipping...
# Processing city #3 in group #12 | kulhudhuffushi
# Processing city #4 in group #12 | bissora
# Processing city #5 in group #12 | senekal
# Processing city #6 in group #12 | ramnagar
# Processing city #7 in group #12 | burica
# burica has an error. Skipping...
# Processing city #8 in group #12 | prainha
# Processing city #9 in group #12 | kathmandu
# Processing city #10 in group #12 | palm coast
# Processing city #11 in group #12 | damghan
# Processing city #12 in group #12 | kang
# Processing city #13 in group #12 | menongue
# Processing city #14 in group #12 | los llanos de aridane
# Processing city #15 in group #12 | nang rong
# Processing city #16 in group #12 | porto uniao
# Processing city #17 in group #12 | port alberni
# Processing city #18 in group #12 | sokoni
# Processing city #19 in group #12 | pampa
# Processing city #20 in group #12 | aitape
# Processing city #21 in group #12 | avera
# Processing city #22 in group #12 | araouane
# Processing city #23 in group #12 | metro
# Processing city #24 in group #12 | muros
# Processing city #25 in group #12 | asandh
# Processing city #26 in group #12 | berlevag
# Processing city #27 in group #12 | pecos
# Processing city #28 in group #12 | katobu
# Processing city #29 in group #12 | tautira
# Processing city #30 in group #12 | alcudia
# Processing city #31 in group #12 | george town
# Processing city #32 in group #12 | buala
# Processing city #33 in group #12 | petropavlovsk-kamchatskiy
# Processing city #34 in group #12 | malwan
# malwan has an error. Skipping...
# Processing city #35 in group #12 | guerrero negro
# Processing city #36 in group #12 | rudbar
# Processing city #37 in group #12 | la romana
# Processing city #38 in group #12 | melito di porto salvo
# Processing city #39 in group #12 | temaraia
# temaraia has an error. Skipping...
# Processing city #40 in group #12 | lower hutt
# Processing city #41 in group #12 | yarada
# Processing city #42 in group #12 | kinsale
# Processing city #43 in group #12 | miramar
# Processing city #44 in group #12 | macusani
# Processing city #45 in group #12 | buchanan
# Processing city #46 in group #12 | kavieng
# Processing city #47 in group #12 | williams lake
# Processing city #48 in group #12 | khonuu
# khonuu has an error. Skipping...
# Processing city #49 in group #12 | ambilobe
# Processing city #50 in group #12 | burnie
# Processing city #1 in group #13 | jay
# Processing city #2 in group #13 | baoro
# Processing city #3 in group #13 | ketchikan
# Processing city #4 in group #13 | karratha
# Processing city #5 in group #13 | kaduqli
# Processing city #6 in group #13 | paamiut
# Processing city #7 in group #13 | crevenicu
# Processing city #8 in group #13 | anloga
# Processing city #9 in group #13 | abu samrah
# Processing city #10 in group #13 | sisimiut
# Processing city #11 in group #13 | orange cove
# Processing city #12 in group #13 | pilar
# Processing city #13 in group #13 | san mateo del mar
# Processing city #14 in group #13 | lemon tree passage
# Processing city #15 in group #13 | snezhnogorsk
# Processing city #16 in group #13 | pekalongan
# Processing city #17 in group #13 | muzquiz
# muzquiz has an error. Skipping...
# Processing city #18 in group #13 | muisne
# Processing city #19 in group #13 | sobolevo
# Processing city #20 in group #13 | sun valley
# Processing city #21 in group #13 | raudeberg
# Processing city #22 in group #13 | lavrentiya
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_pd = pd.DataFrame(city_data)
city_data_pd.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        hilo  19.7297 -155.0900     74.25        91         100        6.91
# 1       rocha -34.4833  -54.3333     52.52        97           3        4.43
# 2  rock sound  24.9000  -76.2000     80.53        71           2       22.03
# 3     hualmay -11.0964  -77.6139     61.16        87           7        8.32
# 4      riyadh  24.6877   46.7219     77.14        32           9       14.81
#
#   Country        Date
# 0      US  1667717337
# 1      UY  1667717426
# 2      BS  1667717429
# 3      PE  1667717431
# 4      SA  1667717401

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  576.000000  576.000000  576.000000  576.000000  576.000000  576.000000
# mean    19.943082   19.794941   59.206545   71.256944   59.673611    7.836406
# std     33.165787   90.656998   22.530745   21.241386   40.820597    5.284715
# min    -54.800000 -179.166700  -24.030000    1.000000    0.000000    0.000000
# 25%     -7.409500  -58.931775   45.377500   61.000000   11.750000    4.000000
# 50%     24.410300   25.150750   65.385000   76.000000   75.000000    6.780000
# 75%     47.602525  100.707400   77.102500   88.000000  100.000000   10.487500
# max     78.218600  178.416700   94.590000  100.000000  100.000000   39.120000
#
#                Date
# count  5.760000e+02
# mean   1.667718e+09
# std    4.797139e+02
# min    1.667717e+09
# 25%    1.667718e+09
# 50%    1.667718e+09
# 75%    1.667719e+09
# max    1.667719e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Get the indices of cities that have humidity over 100%.
dirty_city_data = city_data_pd[(city_data_pd["Humidity"] > 100)].index

print(dirty_city_data)
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data_pd.drop(dirty_city_data, inplace=False)
clean_city_data.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        hilo  19.7297 -155.0900     74.25        91         100        6.91
# 1       rocha -34.4833  -54.3333     52.52        97           3        4.43
# 2  rock sound  24.9000  -76.2000     80.53        71           2       22.03
# 3     hualmay -11.0964  -77.6139     61.16        87           7        8.32
# 4      riyadh  24.6877   46.7219     77.14        32           9       14.81
#
#   Country        Date
# 0      US  1667717337
# 1      UY  1667717426
# 2      BS  1667717429
# 3      PE  1667717431
# 4      SA  1667717401

# %%
# Extract relevant fields from the data frame
lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

# Export the City_Data into a csv
clean_city_data.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(lats, max_temps, edgecolor="black", linewidths=1, marker="o",
           alpha=0.8,label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(lats, humidity, edgecolor="black", linewidths=1, marker="o",
           alpha=0.8,label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(lats, cloudiness, edgecolor="black", linewidths=1, marker="o",
           alpha=0.8,label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(lats, wind_speed, edgecolor="black", linewidths=1, marker="o",
           alpha=0.8,label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    #run a regression on the hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "% + " + str(round(intercept,2))
    
    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values, "r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create Northern and Southern Hemispher DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (6,30))
# Out:
# The r-value is: 0.7670683671533015

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (6,30))
# Out:
# The r-value is: 0.2947629468641987

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (6,30))
# Out:
# The r-value is: 0.1200822179223895

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (6,30))
# Out:
# The r-value is: 0.013825430706923292

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (6,30))
# Out:
# The r-value is: 0.06187529704629455

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (6,30))
# Out:
# The r-value is: 0.09740513338996784

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (6,30))
# Out:
# The r-value is: 0.052983165249529666

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (6,30))
# Out:
# The r-value is: 0.029920787203186826
